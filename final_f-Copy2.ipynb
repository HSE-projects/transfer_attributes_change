# %%
import pandas as pd
import catboost as cb
from matplotlib import pyplot as plt 
import seaborn as sns
from catboost import CatBoostRegressor
import numpy as np
import yaml
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
with open('param.yaml') as f: target_feature_dict = yaml.load(f)
with open('extra_ft_dict') as f: extra_ft_dict = yaml.load(f)
# Out:
# <ipython-input-2-8ee37095d917>:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   with open('param.yaml') as f: target_feature_dict = yaml.load(f)
# <ipython-input-2-8ee37095d917>:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   with open('extra_ft_dict') as f: extra_ft_dict = yaml.load(f)

# %%
def get_normalized_data(train_data, val_data, test_data, features_arr, target_arr, extra_ft): # Возвращает датасэты с нормированными данными
    ft_arr = features_arr.copy()
    tg_arr = target_arr.copy()
    if 'minutes_x' not in ft_arr:
        ft_arr.append('minutes_x')
    if 'minutes_y' not in tg_arr:
        tg_arr.append('minutes_y')
    new_train = train_data[ft_arr + tg_arr + extra_ft].copy()
    new_val = val_data[ft_arr + tg_arr + extra_ft].copy()
    new_test = test_data[ft_arr + tg_arr + extra_ft].copy()
    
    div_tg_cols = []
    div_ft_cols = []
    for col in ft_arr:
        if col == 'minutes_x':
            continue
        if new_train[col].dtype == np.float64 and 'per90' not in col and 'pct' not in col and 'possession' not in col and '_old' not in col and '_new' not in col:
            div_ft_cols.append(col)
    
    for col in tg_arr:
        if col == 'minutes_y':
            continue
        if new_train[col].dtype == np.float64 and 'per90' not in col and 'pct' not in col and 'possession' not in col and '_old' not in col and '_new' not in col:
            div_tg_cols.append(col)
    
    #нормируем по минутам
    new_train[div_tg_cols + div_ft_cols] = new_train[div_tg_cols + div_ft_cols].apply(lambda x : x * 90)
    new_train[div_ft_cols] = new_train[div_ft_cols].div(new_train.minutes_x, axis=0).copy()
    new_train[div_tg_cols] = new_train[div_tg_cols].div(new_train.minutes_y, axis=0).copy()
    
    new_val[div_tg_cols + div_ft_cols] = new_val[div_tg_cols + div_ft_cols].apply(lambda x : x * 90)
    new_val[div_ft_cols] = new_val[div_ft_cols].div(new_val.minutes_x, axis=0).copy()
    new_val[div_tg_cols] = new_val[div_tg_cols].div(new_val.minutes_y, axis=0).copy()
    
    new_test[div_tg_cols + div_ft_cols] = new_test[div_tg_cols + div_ft_cols].apply(lambda x : x * 90)
    new_test[div_ft_cols] = new_test[div_ft_cols].div(new_test.minutes_x, axis=0).copy()
    new_test[div_tg_cols] = new_test[div_tg_cols].div(new_test.minutes_y, axis=0).copy()
    
    new_train.dropna(inplace=True, axis=0, subset=extra_ft)
    new_val.dropna(inplace=True, axis=0, subset=extra_ft)
    new_test.dropna(inplace=True, axis=0, subset=extra_ft)
    
    #PCA + StantardScaler
    if ('position_x' in ft_arr):
        ft_arr.remove('position_x')
    if ('minutes_x' in ft_arr):
        ft_arr.remove('minutes_x')
    if ('minutes_y' in ft_arr):
        ft_arr.remove('minutes_y')
    SC = StandardScaler()
    new_train[ft_arr] = SC.fit_transform(new_train[ft_arr])
    new_val[ft_arr] = SC.transform(new_val[ft_arr])
    new_test[ft_arr] = SC.transform(new_test[ft_arr])
    
    
    pca = PCA(n_components=4)
    
    x = new_train[extra_ft].copy()
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 'principal component 3', 'principal component 4'])
    new_train = pd.concat([new_train[features_arr + target_arr], principalDf], axis=1)
    
    x = new_val[extra_ft].copy()
    principalComponents = pca.transform(x)
    principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 'principal component 3', 'principal component 4'])
    new_val = pd.concat([new_val[features_arr + target_arr], principalDf], axis=1)
    
    x = new_test[extra_ft].copy()
    principalComponents = pca.transform(x)
    principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 'principal component 3', 'principal component 4'])
    new_test = pd.concat([new_test[features_arr + target_arr], principalDf], axis=1)
    
    
    return new_train, new_val, new_test
    
def get_cat_model(features_arr, target_arr, train_data, val_data, metric = 'RMSE', cat_features_names = [], plt = True):
    #подаем названия столбцов признаков и целевых переменных +
    # + DataFrame с данными. loss_f -- строка-название функции потерь
    df = train_data[features_arr + target_arr].copy()
    df.dropna(subset = target_arr, inplace=True) # удаляем строки, где целевая переменнная = NaN
    train_x = df[features_arr].copy()
    train_y = df[target_arr].copy()  
    
    
    df = val_data[features_arr + target_arr].copy()
    df.dropna(subset = target_arr, inplace=True) # удаляем строки, где целевая переменнная = NaN
    val_x = df[features_arr].copy()
    val_y = df[target_arr].copy()
    
    
    cat_features = [train_x.columns.get_loc(col) for col in cat_features_names]
    SEED = 100
    params = {'loss_function': metric, # objective function
          'eval_metric': metric, # metric
          'verbose': False, # output to stdout info about training process every 200 iterations
          'random_seed': SEED,
          'cat_features' : cat_features, # вектор с номерами столбцов, считая от 0
         }
    
    
    mdl = CatBoostRegressor(**params)
    mdl.fit(train_x, train_y, # data to train on 
          eval_set=(val_x, val_y), # data to validate on
          use_best_model=True, # True if we don't want to save trees created after iteration with the best validation score
          plot=plt # True for visualization of the training process (it is not shown in a published kernel - try executing this code)
         );
    return mdl


def get_test_res(model, features_arr, target_arr, test_data):  #predict. Возвращаем DataFrame с результатом
    
    df = test_data[features_arr + target_arr].copy()
    df.dropna(subset = target_arr, inplace=True) # удаляем строки, где целевая переменнная = NaN
    test_x = df[features_arr]
    
    ans = pd.DataFrame(model.predict(test_x), columns=target_arr)
    return ans

def MAPE(first, second):
    
    error = 0
    for i in first.columns:
        error += min(1.5, abs(float(first[i]) - float(second[i])) / abs(float(second[i])))
    error /= len(first.columns)
    return error

def test_quality(test_data, target_arr, result, loss_func = MAPE):
                                                                                
    test_y = test_data[target_arr].copy()
    test_y.dropna(subset = target_arr, inplace=True) # удаляем строки, где целевая переменнная = NaN
    
    min_error = -1 # минимальное значение ошибки
    max_error = -1
    error = 0
    size = result.shape
    for i in range(0,size[0]):
        first = pd.DataFrame(test_y.iloc[i:(i+1), :])
        second = pd.DataFrame(result.iloc[i:(i+1), :])
        curr_error = loss_func(first, second)
        if min_error == -1 or min_error > curr_error:
            min_error = curr_error
        if max_error == -1 or curr_error > max_error:
            max_error = curr_error
        error += curr_error
    error /= size[0]
    
    return error, min_error, max_error
    
def print_feature_importance(model): # Рисуем график "важности" признаков
    
    feature_importance_df = pd.DataFrame(model.get_feature_importance(prettified=True), columns=['Feature Id', 'Importances'])
    plt.figure(figsize=(12, 6));
    sns.barplot(x="Importances", y="Feature Id", data=feature_importance_df);
    plt.title('CatBoost features importance:');
    

#Шаблон итоговой функции
def build_model(train_dt, val_dt, test_dt, position, ft_arr, target_, extra_ft = [], print_plot=False): 
    #В первых трех аргументах передаем путь до соответствущих табличек
    cat_ft = []
    ft_arr_ = ft_arr.copy()
    if (position == 'all'):
        ft_arr_.append('position_x')
        cat_ft.append('position_x')
    
    #отбираем признаки для PCA
    tmp = []
    for i in extra_ft:
        if i not in ft_arr_:
            tmp.append(i)
    extra_ft_ = tmp
    #грузим таблицы
    train_dt = pd.read_csv(train_dt)
    val_dt = pd.read_csv(val_dt)
    test_dt = pd.read_csv(test_dt)
    
    
    train_, val_, test_ = get_normalized_data(train_dt, val_dt, test_dt, ft_arr_, target_, extra_ft_)
    
    
    
    
    model_cat_MAPE = get_cat_model(ft_arr_, target_, train_, val_, 'MAPE', cat_ft, False)
    
    #значение на test
    res_cat_MAPE_test = get_test_res(model_cat_MAPE, ft_arr_, target_, test_)
    
    #значение на val
    res_cat_MAPE_val = get_test_res(model_cat_MAPE, ft_arr_, target_, val_)
    
    
    res_cat_MAPE_error_test, res_cat_MAPE_min_error_test, res_cat_MAPE_max_error_test = test_quality(test_, target_, res_cat_MAPE_test, MAPE)
    res_cat_MAPE_error_val, res_cat_MAPE_min_error_val, res_cat_MAPE_max_error_val = test_quality(val_, target_, res_cat_MAPE_val, MAPE)
    
    print(f'Target: {target_[0]}')
    print(f'Position: {position}')
    #print(f'MAPE:\naverage error: {res_cat_MAPE_error_val}\nmin error: {res_cat_MAPE_min_error_val}\nmax error: {res_cat_MAPE_max_error_val}')
    print('TEST ERROR')
    print(f'MAPE:\naverage error: {res_cat_MAPE_error_test}\nmin error: {res_cat_MAPE_min_error_test}\nmax error: {res_cat_MAPE_max_error_test}')
    return pd.DataFrame(res_cat_MAPE_test)
    #return res_cat_MAPE_error_test

# %% [markdown]
# build_model(path_train, path_val, path_test, position, features_arr, target, extra_features_for_PCA)

# %%
build_model('data replaced/Fullbacks_train.csv', 'data replaced/Fullbacks_val.csv', 'data replaced/Fullbacks_test.csv', 'FB', target_feature_dict['passes_pct_y'], ['passes_pct_y'], extra_ft_dict['FB'])
# Out:
# Target: passes_pct_y
# Position: FB
# TEST ERROR
# MAPE:
# average error: 0.05787362058274148
# min error: 0.00039570902915793833
# max error: 0.20250291931799516
#     passes_pct_y
# 0      72.486487
# 1      81.653365
# 2      74.533020
# 3      80.005780
# 4      72.575601
# 5      77.168424
# 6      80.835085
# 7      79.205328
# 8      80.603264
# 9      71.698487
# 10     73.329017
# 11     80.027328
# 12     82.113767
# 13     74.580583
# 14     78.564367
# 15     77.705077
# 16     76.430798
# 17     76.153141
# 18     72.829243
# 19     77.910966
# 20     76.375938
# 21     79.604962
# 22     73.263855
# 23     74.459992
# 24     79.671032
# 25     78.081660
# 26     77.794995
# 27     79.183507
# 28     81.643661
# 29     82.077393
# 30     81.199457

# %%
path_dict = {}
path_dict['CB'] = 'data replaced/Centerbacks'
path_dict['FB'] = 'data replaced/Fullbacks'
path_dict['MID'] = 'data replaced/Midfielders'
path_dict['ST'] = 'data replaced/Forwards'
path_dict['WIN'] = 'data replaced/Wingers'
path_dict['all'] = 'all'

# %%
res = []
path_dict = {}
path_dict['CB'] = 'data replaced/Centerbacks'
path_dict['FB'] = 'data replaced/Fullbacks'
path_dict['MID'] = 'data replaced/Midfielders'
path_dict['ST'] = 'data replaced/Forwards'
path_dict['WIN'] = 'data replaced/Wingers'
path_dict['all'] = 'all'
target = ['aerials_won_y', 'carry_progressive_distance_y',
       'crosses_y', 'dribbles_completed_pct_y', 'gca_per90_y',
       'interceptions_y', 'npxg_per90_y', 'npxg_xa_per90_y',
       'passes_completed_y', 'passes_into_penalty_area_y', 'passes_pct_y',
       'passes_progressive_distance_y', 'pressures_y', 'sca_per90_y',
       'shots_total_per90_y', 'tackles_won_y', 'tackles_y', 'touches_y']
cols =['CB', 'FB', 'MID', 'ST', 'WIN', 'all']
main = []
for i in cols:
    curr_arr = []
    for j in target:
        curr_arr.append(build_model(path_dict[i] + '_train.csv', path_dict[i] + '_val.csv', path_dict[i] + '_test.csv', i, target_feature_dict[j], [j], extra_ft_dict[i]))
    main.append(curr_arr)
# Out:
# Target: aerials_won_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.21821876572909293
# min error: 0.007783434117769844
# max error: 0.5065103292415875
#
# TEST ERROR
# MAPE:
# average error: 0.2866426308738259
# min error: 0.004738647404470129
# max error: 0.7167547470989647
# Target: carry_progressive_distance_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.2359397908067981
# min error: 0.01845357907298476
# max error: 0.7047422411329068
#
# TEST ERROR
# MAPE:
# average error: 0.3600503505685473
# min error: 0.01876853184269865
# max error: 1.4285569290128277
# Target: crosses_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.6178063910917544
# min error: 0.07948706013471467
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.8888979801433079
# min error: 0.11469217429009752
# max error: 1.5
# Target: dribbles_completed_pct_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.2741257032048215
# min error: 0.07761652797234879
# max error: 0.5753188767097993
#
# TEST ERROR
# MAPE:
# average error: 0.33224629120578236
# min error: 0.029821215803500674
# max error: 1.3156632046632932
# Target: gca_per90_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 1.0249861229988706
# min error: 0.05795630403163397
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.9211667354848995
# min error: 0.01958012862677984
# max error: 1.5
# Target: interceptions_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.39357096929574487
# min error: 0.059112327480169535
# max error: 0.8413465136792219
#
# TEST ERROR
# MAPE:
# average error: 0.37067403290507145
# min error: 0.011340627282869506
# max error: 1.5
# Target: npxg_per90_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.6565693909295689
# min error: 0.06753087982701679
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5916020999988642
# min error: 0.004369867091351141
# max error: 1.5
# Target: npxg_xa_per90_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.5953310367722352
# min error: 0.058963000165940714
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.6193861159748901
# min error: 0.0058530977618286165
# max error: 1.5
# Target: passes_completed_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.1434376817163883
# min error: 0.0012435560119135763
# max error: 0.3147706067605887
#
# TEST ERROR
# MAPE:
# average error: 0.18787476843729475
# min error: 0.007930828255362446
# max error: 0.6379028523383969
# Target: passes_into_penalty_area_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.6808877748206864
# min error: 0.065261965966712
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.6737515307445807
# min error: 0.0065165746755392415
# max error: 1.5
# Target: passes_pct_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.03321832490403198
# min error: 0.003759891098965233
# max error: 0.0843652013084099
#
# TEST ERROR
# MAPE:
# average error: 0.04287489680008517
# min error: 0.0010129297402708367
# max error: 0.16591339742868688
# Target: passes_progressive_distance_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.14066057750313066
# min error: 0.008323031302177266
# max error: 0.3258270900639189
#
# TEST ERROR
# MAPE:
# average error: 0.1957618818558881
# min error: 0.016222997995405265
# max error: 0.49164816073764406
# Target: pressures_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.21129888718929957
# min error: 0.008677979500294388
# max error: 0.6634140340846401
#
# TEST ERROR
# MAPE:
# average error: 0.2564794095814131
# min error: 0.008430050740521111
# max error: 0.7449627574900495
# Target: sca_per90_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.2785652067307221
# min error: 0.004196050744200435
# max error: 0.673880252743459
#
# TEST ERROR
# MAPE:
# average error: 0.471873796065005
# min error: 0.03362359895671971
# max error: 1.1790257538386835
# Target: shots_total_per90_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.5978617959379601
# min error: 0.018525784176345202
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.4547516662714686
# min error: 0.0040506285870142746
# max error: 1.5
# Target: tackles_won_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.33006923417712947
# min error: 0.012826029961319825
# max error: 1.028371017007366
#
# TEST ERROR
# MAPE:
# average error: 0.34409967305242856
# min error: 0.0014040492790491107
# max error: 0.9979831842624886
# Target: tackles_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.36664405700957364
# min error: 0.003930839036626956
# max error: 1.1160711482320074
#
# TEST ERROR
# MAPE:
# average error: 0.4057113423479839
# min error: 0.014762101341785957
# max error: 0.9337095373547922
# Target: touches_y
# Position: CB
# VAL ERROR
# MAPE:
# average error: 0.08272386544606052
# min error: 0.004304855836684966
# max error: 0.1693175145515277
#
# TEST ERROR
# MAPE:
# average error: 0.12048937213437957
# min error: 0.0013253265914562194
# max error: 0.31942375672227047
# Target: aerials_won_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.36932073170065804
# min error: 0.08915191855884569
# max error: 0.8793070026441736
#
# TEST ERROR
# MAPE:
# average error: 0.3719094913275686
# min error: 0.011243605282430463
# max error: 1.2733039800492292
# Target: carry_progressive_distance_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.19445122110147958
# min error: 0.010982891016632725
# max error: 0.6007639545877186
#
# TEST ERROR
# MAPE:
# average error: 0.25839537189412876
# min error: 0.005297754153127377
# max error: 1.2078227744093029
# Target: crosses_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.5192303165440423
# min error: 0.034908151954337906
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.4124237473032133
# min error: 0.01299143413829323
# max error: 1.2266070157811924
# Target: dribbles_completed_pct_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.08716433887700856
# min error: 0.0005813144928057057
# max error: 0.49753922598786277
#
# TEST ERROR
# MAPE:
# average error: 0.1860054122543354
# min error: 0.00340337203140351
# max error: 0.5502142820510256
# Target: gca_per90_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.4150995781888978
# min error: 0.024211954098048098
# max error: 1.0
#
# TEST ERROR
# MAPE:
# average error: 0.6825521905031158
# min error: 0.005106835924044141
# max error: 1.5
# Target: interceptions_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.32299485261492544
# min error: 0.007390156658023852
# max error: 0.827010263659274
#
# TEST ERROR
# MAPE:
# average error: 0.36238931342645647
# min error: 0.034751808312201635
# max error: 1.172674472366772
# Target: npxg_per90_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.5747206734787272
# min error: 0.007081330887785023
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.7557893059698998
# min error: 0.0020416304912812392
# max error: 1.5
# Target: npxg_xa_per90_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.29428960858181485
# min error: 0.0014597918945148463
# max error: 0.646901162890077
#
# TEST ERROR
# MAPE:
# average error: 0.39823863175287116
# min error: 0.02123159047003834
# max error: 1.5
# Target: passes_completed_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.17185254375180012
# min error: 0.0023373083745451685
# max error: 0.4021069163893837
#
# TEST ERROR
# MAPE:
# average error: 0.14014589952336307
# min error: 0.004663927587818082
# max error: 0.3409542924064444
# Target: passes_into_penalty_area_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.40361647894499414
# min error: 0.009071159213591699
# max error: 1.215421600673926
#
# TEST ERROR
# MAPE:
# average error: 0.3744186123465797
# min error: 0.01911752334623212
# max error: 1.5
# Target: passes_pct_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.030990925449810698
# min error: 0.001731964456456936
# max error: 0.078630189219709
#
# TEST ERROR
# MAPE:
# average error: 0.05787362058274148
# min error: 0.00039570902915793833
# max error: 0.20250291931799516
# Target: passes_progressive_distance_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.24449603326607952
# min error: 0.06297609073984425
# max error: 0.5491946131330443
#
# TEST ERROR
# MAPE:
# average error: 0.15799247331486602
# min error: 0.014381077469182615
# max error: 0.546633707752844
# Target: pressures_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.1323768441368153
# min error: 0.014862314989707184
# max error: 0.41895687916951335
#
# TEST ERROR
# MAPE:
# average error: 0.1799143326840045
# min error: 0.004091412135232378
# max error: 0.7382959797569995
# Target: sca_per90_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.2968640488660589
# min error: 0.006393225884504185
# max error: 0.6237331142895505
#
# TEST ERROR
# MAPE:
# average error: 0.40337283362897836
# min error: 0.002412974741808117
# max error: 1.5
# Target: shots_total_per90_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.3757509002187489
# min error: 0.022942620761655944
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.6068389776279189
# min error: 0.0014377359051233845
# max error: 1.4057618266968823
# Target: tackles_won_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.3613408401530815
# min error: 0.03875752806000724
# max error: 0.9233223134264624
#
# TEST ERROR
# MAPE:
# average error: 0.305407414829219
# min error: 0.024061722795660018
# max error: 1.3465089080601413
# Target: tackles_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.2749009337691554
# min error: 0.04457988565188956
# max error: 0.5178236029367305
#
# TEST ERROR
# MAPE:
# average error: 0.22473520009224648
# min error: 0.0005766315190283721
# max error: 0.8896438407526551
# Target: touches_y
# Position: FB
# VAL ERROR
# MAPE:
# average error: 0.12047229533680201
# min error: 0.02160916567771665
# max error: 0.2269575481479239
#
# TEST ERROR
# MAPE:
# average error: 0.09584142505316381
# min error: 0.002962841921813299
# max error: 0.25613838247583204
# Target: aerials_won_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.49718503599370256
# min error: 0.026589748391889507
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.42066357075434935
# min error: 0.0017013967925441696
# max error: 1.5
# Target: carry_progressive_distance_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.3390182838306946
# min error: 0.004000139635410059
# max error: 1.2269943158666226
#
# TEST ERROR
# MAPE:
# average error: 0.256275781725466
# min error: 0.011690015148783454
# max error: 0.914155402614736
# Target: crosses_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.5436748514863959
# min error: 0.005024447232828742
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5907266741022014
# min error: 0.015761827657380774
# max error: 1.5
# Target: dribbles_completed_pct_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.29633410906737034
# min error: 0.004351554161242632
# max error: 1.0
#
# TEST ERROR
# MAPE:
# average error: 0.37281978534724414
# min error: 0.027161416267936483
# max error: 1.0501412682994054
# Target: gca_per90_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.6823460282622601
# min error: 0.052541788383419316
# max error: 1.1123139596487133
#
# TEST ERROR
# MAPE:
# average error: 0.6165303890801523
# min error: 0.0032208703127794562
# max error: 1.5
# Target: interceptions_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.3689341426286315
# min error: 0.0036218200649363007
# max error: 1.3716722152280185
#
# TEST ERROR
# MAPE:
# average error: 0.356526420449492
# min error: 0.00896959071774693
# max error: 1.5
# Target: npxg_per90_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.4239923470810682
# min error: 0.0212401152976122
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5584243441828833
# min error: 0.02414958640287498
# max error: 1.5
# Target: npxg_xa_per90_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.4342832180745812
# min error: 0.007030660969623007
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.4522794538643118
# min error: 0.041649625816782915
# max error: 1.5
# Target: passes_completed_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.22346186166476498
# min error: 0.005720090185175758
# max error: 0.6295381944684689
#
# TEST ERROR
# MAPE:
# average error: 0.15073750654441107
# min error: 0.004171844509453834
# max error: 0.5143848843106785
# Target: passes_into_penalty_area_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.39785493790357507
# min error: 0.005380546553626123
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.38699956507068933
# min error: 0.012558358610196408
# max error: 1.2935687442307973
# Target: passes_pct_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.05859507996218873
# min error: 0.00023351164443486403
# max error: 0.21222330016555227
#
# TEST ERROR
# MAPE:
# average error: 0.04228772812855981
# min error: 0.000327573381481377
# max error: 0.2131128144002755
# Target: passes_progressive_distance_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.27247820938592116
# min error: 0.03748622524424701
# max error: 1.3349786511096622
#
# TEST ERROR
# MAPE:
# average error: 0.20780612880703966
# min error: 0.0002244164861127816
# max error: 0.5054127092073629
# Target: pressures_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.19691899354904074
# min error: 0.01247366551183913
# max error: 0.7528460201776029
#
# TEST ERROR
# MAPE:
# average error: 0.19766658778475052
# min error: 0.008065030958810903
# max error: 1.0168560057193616
# Target: sca_per90_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.33921583459907856
# min error: 0.010966426672227317
# max error: 1.1332337304157725
#
# TEST ERROR
# MAPE:
# average error: 0.3095678932856881
# min error: 0.0041145207384819926
# max error: 1.1606938478873783
# Target: shots_total_per90_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.25605357529593725
# min error: 0.0034160637563431036
# max error: 0.7857519348521123
#
# TEST ERROR
# MAPE:
# average error: 0.47850321091299436
# min error: 0.028915751686913963
# max error: 1.5
# Target: tackles_won_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.27387369371564096
# min error: 0.01769057562692152
# max error: 0.8901634351911358
#
# TEST ERROR
# MAPE:
# average error: 0.3012021597058197
# min error: 0.005485878691680996
# max error: 1.0
# Target: tackles_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.26975990203687294
# min error: 0.0017416511865272048
# max error: 0.7029309847364904
#
# TEST ERROR
# MAPE:
# average error: 0.27786872804264157
# min error: 0.005906941398147106
# max error: 0.943359556221849
# Target: touches_y
# Position: MID
# VAL ERROR
# MAPE:
# average error: 0.1283495592622981
# min error: 0.011509382210555332
# max error: 0.340904011561122
#
# TEST ERROR
# MAPE:
# average error: 0.10844716877667969
# min error: 0.004971619827401038
# max error: 0.3673456657300662
# Target: aerials_won_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.5348428545367402
# min error: 0.005188175804947025
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5801253718219919
# min error: 0.07744235534416792
# max error: 1.5
# Target: carry_progressive_distance_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.646944984571767
# min error: 0.10188656540785353
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.6585600308611382
# min error: 0.014353268333146168
# max error: 1.5
# Target: crosses_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.5798649725219652
# min error: 0.01944118023035395
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.8099621471220144
# min error: 0.016409495956650057
# max error: 1.5
# Target: dribbles_completed_pct_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.21396648275346336
# min error: 0.0033294161840239944
# max error: 1.3570200520792624
#
# TEST ERROR
# MAPE:
# average error: 0.35095262575930836
# min error: 0.0030960939908295827
# max error: 1.1489458288252286
# Target: gca_per90_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.5121215327844734
# min error: 0.002913760176915597
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5824940194403285
# min error: 7.614678996059187e-05
# max error: 1.5
# Target: interceptions_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.6211783060216572
# min error: 0.05238474071597215
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.7104537091558202
# min error: 0.04155864663274404
# max error: 1.5
# Target: npxg_per90_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.38816614793147247
# min error: 0.004132763931546153
# max error: 1.0
#
# TEST ERROR
# MAPE:
# average error: 0.3028772245182839
# min error: 0.00392137148801587
# max error: 1.212330280592318
# Target: npxg_xa_per90_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.3152572281844228
# min error: 0.0810472465520881
# max error: 1.0
#
# TEST ERROR
# MAPE:
# average error: 0.24418018398824815
# min error: 0.01586028033301143
# max error: 1.2986846494174609
# Target: passes_completed_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.1832164114103965
# min error: 0.0391007673612588
# max error: 0.40588094927523644
#
# TEST ERROR
# MAPE:
# average error: 0.26600491746986765
# min error: 0.011486295725654483
# max error: 1.4678712679567765
# Target: passes_into_penalty_area_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.47525413725527027
# min error: 0.008637543691889828
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5385616625442113
# min error: 0.05147269633271642
# max error: 1.5
# Target: passes_pct_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.04734824026775648
# min error: 0.0010596079537448864
# max error: 0.1400038349474203
#
# TEST ERROR
# MAPE:
# average error: 0.05276657577152708
# min error: 0.004153693630814509
# max error: 0.14836097441022889
# Target: passes_progressive_distance_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.5206481598507553
# min error: 8.887672671696969e-05
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.646578216117875
# min error: 0.019377509770880954
# max error: 1.5
# Target: pressures_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.2659444053512071
# min error: 0.08607226080460528
# max error: 0.8632122396149361
#
# TEST ERROR
# MAPE:
# average error: 0.21757601374068253
# min error: 0.00014538593288892894
# max error: 0.7540030714169148
# Target: sca_per90_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.34007866265651593
# min error: 0.029287644427958295
# max error: 0.7849002927401169
#
# TEST ERROR
# MAPE:
# average error: 0.38657429897741336
# min error: 0.011272050737921379
# max error: 1.5
# Target: shots_total_per90_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.3053457914682535
# min error: 0.004508192691307721
# max error: 1.2320407409240421
#
# TEST ERROR
# MAPE:
# average error: 0.40155799692757027
# min error: 0.014039077969549046
# max error: 1.2956604418433004
# Target: tackles_won_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.3598972157101643
# min error: 0.0024492951392732065
# max error: 0.7903012834430744
#
# TEST ERROR
# MAPE:
# average error: 0.5969766694510752
# min error: 0.03523749869757309
# max error: 1.5
# Target: tackles_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.44138454625554613
# min error: 0.035506993308927905
# max error: 1.3732752300008801
#
# TEST ERROR
# MAPE:
# average error: 0.694107599649873
# min error: 0.07576130033286863
# max error: 1.5
# Target: touches_y
# Position: ST
# VAL ERROR
# MAPE:
# average error: 0.10095384464079608
# min error: 0.0019372356537550553
# max error: 0.26626047816945847
#
# TEST ERROR
# MAPE:
# average error: 0.1948359675832274
# min error: 0.006819416801927273
# max error: 0.8310227552317654
# Target: aerials_won_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.4428345396954749
# min error: 0.0004718345951663203
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5670904862717804
# min error: 0.004604313413249711
# max error: 1.5
# Target: carry_progressive_distance_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.30230036873073907
# min error: 0.008632441116141231
# max error: 0.7505300021685698
#
# TEST ERROR
# MAPE:
# average error: 0.27487720798250365
# min error: 0.004886837700218889
# max error: 1.097304214663996
# Target: crosses_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.4860055171110108
# min error: 0.04020307123512567
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5772093835404271
# min error: 0.03901170265015538
# max error: 1.5
# Target: dribbles_completed_pct_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.16397409444266964
# min error: 0.006048489515236239
# max error: 0.3693361993872068
#
# TEST ERROR
# MAPE:
# average error: 0.23540185200359337
# min error: 0.0026989553915093526
# max error: 0.6706303370757334
# Target: gca_per90_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.4753284372402306
# min error: 0.003331615717737157
# max error: 1.3045885060488127
#
# TEST ERROR
# MAPE:
# average error: 0.49802822782026535
# min error: 0.013452304307420261
# max error: 1.4420336170473202
# Target: interceptions_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.5090569121502287
# min error: 0.01647462134248299
# max error: 1.109204262662176
#
# TEST ERROR
# MAPE:
# average error: 0.4544244515547028
# min error: 0.0224687935262999
# max error: 1.5
# Target: npxg_per90_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.4150688076686634
# min error: 0.0005607902006782171
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.33397981410214156
# min error: 0.0033388420684017503
# max error: 0.8970538472712027
# Target: npxg_xa_per90_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.30400086702869744
# min error: 0.006076633104473179
# max error: 0.8987014995077202
#
# TEST ERROR
# MAPE:
# average error: 0.2884509015454944
# min error: 0.010336581189162027
# max error: 1.419950627767008
# Target: passes_completed_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.19039289487155903
# min error: 0.009106722357090176
# max error: 0.43831487554787685
#
# TEST ERROR
# MAPE:
# average error: 0.2259708186923946
# min error: 0.010074264940251397
# max error: 0.8165744701239979
# Target: passes_into_penalty_area_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.34842407355286314
# min error: 0.02729268181418251
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.34850103504077984
# min error: 0.014751564957101183
# max error: 1.0632672975862807
# Target: passes_pct_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.04997622038522433
# min error: 0.00022022883953006964
# max error: 0.1450535633608328
#
# TEST ERROR
# MAPE:
# average error: 0.05174264739991718
# min error: 0.0003950901151438681
# max error: 0.17721359593623762
# Target: passes_progressive_distance_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.3881234861165661
# min error: 0.010952251202343418
# max error: 1.132176918724513
#
# TEST ERROR
# MAPE:
# average error: 0.38609197775557674
# min error: 0.026121668573957712
# max error: 1.5
# Target: pressures_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.2085295228900994
# min error: 0.0051393060236046475
# max error: 0.39952962360941413
#
# TEST ERROR
# MAPE:
# average error: 0.18741086734157372
# min error: 0.011686930020004387
# max error: 0.606319284942523
# Target: sca_per90_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.22397466216976689
# min error: 6.599082581250128e-06
# max error: 0.6236708311237157
#
# TEST ERROR
# MAPE:
# average error: 0.2692560352364679
# min error: 0.021585365373346484
# max error: 1.225605812922363
# Target: shots_total_per90_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.37391375734212806
# min error: 0.010512602253175414
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.29197117217804364
# min error: 0.0010091464687895753
# max error: 1.1689192033879
# Target: tackles_won_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.4701020300218699
# min error: 0.010451423900305477
# max error: 1.1264149175680973
#
# TEST ERROR
# MAPE:
# average error: 0.4224547666109339
# min error: 0.030334578868696584
# max error: 1.41681028737902
# Target: tackles_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.34529942539544706
# min error: 0.013475355204475998
# max error: 0.8469994426046948
#
# TEST ERROR
# MAPE:
# average error: 0.38530257148868446
# min error: 0.019563651923604472
# max error: 1.5
# Target: touches_y
# Position: WIN
# VAL ERROR
# MAPE:
# average error: 0.1521581000860678
# min error: 0.008341324900669812
# max error: 0.5678674676380877
#
# TEST ERROR
# MAPE:
# average error: 0.1435635041339344
# min error: 0.0024238500549075676
# max error: 0.4026902215262052
# Target: aerials_won_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.423496483084843
# min error: 0.002645011326418915
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.4330695089631157
# min error: 0.0007078463848714888
# max error: 1.5
# Target: carry_progressive_distance_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.3887981869359668
# min error: 0.004235900237486712
# max error: 1.2821402752295041
#
# TEST ERROR
# MAPE:
# average error: 0.41064131755637484
# min error: 4.0003179265751863e-05
# max error: 1.5
# Target: crosses_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.535060529905268
# min error: 0.01011266816990484
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5757110258973092
# min error: 0.0020478048564890757
# max error: 1.5
# Target: dribbles_completed_pct_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.36004208009412164
# min error: 0.0034618055778246064
# max error: 1.013777308852013
#
# TEST ERROR
# MAPE:
# average error: 0.3816203971083757
# min error: 0.0022015185158124
# max error: 1.4186577526934216
# Target: gca_per90_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.606853829194783
# min error: 0.0024653913470497795
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.6075129623789581
# min error: 0.00010212685265549485
# max error: 1.5
# Target: interceptions_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.44285020946597103
# min error: 0.006814711788105665
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.4493870878568051
# min error: 0.0017616973524610753
# max error: 1.5
# Target: npxg_per90_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.5036153930920231
# min error: 0.001203605317163046
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.5091363973064442
# min error: 0.005608997603893813
# max error: 1.5
# Target: npxg_xa_per90_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.3643098114468381
# min error: 0.00015342378891186292
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.3772591776584842
# min error: 0.0010201726689085288
# max error: 1.5
# Target: passes_completed_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.1908581326717363
# min error: 0.003970483153244946
# max error: 0.731761992776838
#
# TEST ERROR
# MAPE:
# average error: 0.19168964371216934
# min error: 0.0018139968685093174
# max error: 0.7308143608736627
# Target: passes_into_penalty_area_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.4699068451273245
# min error: 0.01261817522024699
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.4183812339204665
# min error: 0.000781316445037566
# max error: 1.5
# Target: passes_pct_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.046629553092346246
# min error: 0.0017862676150893178
# max error: 0.1744311021274779
#
# TEST ERROR
# MAPE:
# average error: 0.04478064095571246
# min error: 3.425402139084702e-05
# max error: 0.17800652124051114
# Target: passes_progressive_distance_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.4941535761117611
# min error: 0.00683565955426559
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.48360519738173813
# min error: 0.0009730318355875967
# max error: 1.5
# Target: pressures_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.2033795945565795
# min error: 0.019563448216463664
# max error: 0.6715348489162482
#
# TEST ERROR
# MAPE:
# average error: 0.20208959829433043
# min error: 0.0033461547970917724
# max error: 0.9562299753204005
# Target: sca_per90_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.31307339127642847
# min error: 0.015135632256070385
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.3235497192184754
# min error: 0.0004553433690809391
# max error: 1.5
# Target: shots_total_per90_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.3735746756108347
# min error: 0.0007814183195481606
# max error: 1.5
#
# TEST ERROR
# MAPE:
# average error: 0.3895063545744005
# min error: 0.00040776953340063556
# max error: 1.5
# Target: tackles_won_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.36819184965686697
# min error: 0.0010727867115208154
# max error: 1.264050502610022
#
# TEST ERROR
# MAPE:
# average error: 0.36774506743303526
# min error: 0.0029230991897176515
# max error: 1.4397327102802573
# Target: tackles_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.34687523565284956
# min error: 0.0014215960049869492
# max error: 1.010329802411596
#
# TEST ERROR
# MAPE:
# average error: 0.35259650780725976
# min error: 0.0019543018989278686
# max error: 1.5
# Target: touches_y
# Position: all
# VAL ERROR
# MAPE:
# average error: 0.11521971541632675
# min error: 4.810234513853065e-05
# max error: 0.41293138084623754
#
# TEST ERROR
# MAPE:
# average error: 0.12524202320740058
# min error: 3.7714380230970094e-05
# max error: 0.794466698492003

# %%
df = pd.DataFrame(main, columns=target)
df.insert(0, 'position', cols)
df
# Out:
#   position  aerials_won_y  carry_progressive_distance_y  crosses_y  \
# 0       CB       0.286643                      0.360050   0.888898
# 1       FB       0.371909                      0.258395   0.412424
# 2      MID       0.420664                      0.256276   0.590727
# 3       ST       0.580125                      0.658560   0.809962
# 4      WIN       0.567090                      0.274877   0.577209
# 5      all       0.433070                      0.410641   0.575711
#
#    dribbles_completed_pct_y  gca_per90_y  interceptions_y  npxg_per90_y  \
# 0                  0.332246     0.921167         0.370674      0.591602
# 1                  0.186005     0.682552         0.362389      0.755789
# 2                  0.372820     0.616530         0.356526      0.558424
# 3                  0.350953     0.582494         0.710454      0.302877
# 4                  0.235402     0.498028         0.454424      0.333980
# 5                  0.381620     0.607513         0.449387      0.509136
#
#    npxg_xa_per90_y  passes_completed_y  passes_into_penalty_area_y  \
# 0         0.619386            0.187875                    0.673752
# 1         0.398239            0.140146                    0.374419
# 2         0.452279            0.150738                    0.387000
# 3         0.244180            0.266005                    0.538562
# 4         0.288451            0.225971                    0.348501
# 5         0.377259            0.191690                    0.418381
#
#    passes_pct_y  passes_progressive_distance_y  pressures_y  sca_per90_y  \
# 0      0.042875                       0.195762     0.256479     0.471874
# 1      0.057874                       0.157992     0.179914     0.403373
# 2      0.042288                       0.207806     0.197667     0.309568
# 3      0.052767                       0.646578     0.217576     0.386574
# 4      0.051743                       0.386092     0.187411     0.269256
# 5      0.044781                       0.483605     0.202090     0.323550
#
#    shots_total_per90_y  tackles_won_y  tackles_y  touches_y
# 0             0.454752       0.344100   0.405711   0.120489
# 1             0.606839       0.305407   0.224735   0.095841
# 2             0.478503       0.301202   0.277869   0.108447
# 3             0.401558       0.596977   0.694108   0.194836
# 4             0.291971       0.422455   0.385303   0.143564
# 5             0.389506       0.367745   0.352597   0.125242

# %%
best = ['passes_completed_y', 'passes_pct_y', 'passes_progressive_distance_y', 'pressures_y', 'touches_y', 'tackles_y']

# %%
average_test = []
cols =['CB', 'FB', 'MID', 'ST', 'WIN', 'all']

for i in cols:
    curr_arr = []
    for j in best:
        curr_res = []
        curr_train = pd.read_csv(path_dict[i] + '_train.csv')
        curr_val = pd.read_csv(path_dict[i] + '_val.csv')
        curr_test = pd.read_csv(path_dict[i] + '_test.csv')
        curr_table = pd.concat([curr_train, curr_val])
        curr_avrg = curr_table[j].mean()
        curr_test = pd.DataFrame(curr_test[j], columns=[j])
        curr_test.dropna(subset = [j], inplace=True)
        ans = []
        for k in range(0, curr_test.shape[0]):
            ans.append(curr_avrg)
        ans = pd.DataFrame(ans, columns=[j])
        err, _, _ = test_quality(curr_test, [j], ans)
        curr_arr.append(err)
    average_test.append(curr_arr)

# %%
avg_res = pd.DataFrame(average_test, columns = best)
avg_res.insert(0, 'position', cols)
avg_res
# Out:
#   position  passes_completed_y  passes_pct_y  passes_progressive_distance_y  \
# 0       CB            0.466758      0.053922                       0.490424
# 1       FB            0.476777      0.062731                       0.525779
# 2      MID            0.449648      0.052054                       0.506420
# 3       ST            0.522882      0.064966                       0.657255
# 4      WIN            0.597525      0.067716                       0.630525
# 5      all            0.573631      0.078796                       0.645234
#
#    pressures_y  touches_y  tackles_y
# 0     0.425088   0.464507   0.515169
# 1     0.504340   0.472100   0.511795
# 2     0.479651   0.434563   0.578156
# 3     0.570592   0.539790   0.685289
# 4     0.571576   0.582870   0.661034
# 5     0.535142   0.533909   0.627728

# %%
avg_res.to_csv('avg_res.csv', index=False)

# %%
df = df[['position'] + best]
df
# Out:
#   position  passes_completed_y  passes_pct_y  passes_progressive_distance_y  \
# 0       CB            0.187875      0.042875                       0.195762
# 1       FB            0.140146      0.057874                       0.157992
# 2      MID            0.150738      0.042288                       0.207806
# 3       ST            0.266005      0.052767                       0.646578
# 4      WIN            0.225971      0.051743                       0.386092
# 5      all            0.191690      0.044781                       0.483605
#
#    pressures_y  touches_y  tackles_y
# 0     0.256479   0.120489   0.405711
# 1     0.179914   0.095841   0.224735
# 2     0.197667   0.108447   0.277869
# 3     0.217576   0.194836   0.694108
# 4     0.187411   0.143564   0.385303
# 5     0.202090   0.125242   0.352597

# %%
res_avg = pd.DataFrame()

# %%
res_avg['passes_completed_y'] = avg_res['passes_completed_y'].mean()
res_avg['passes_pct_y'] = avg_res['passes_pct_y'].mean()
res_avg['passes_progressive_distance_y'] = avg_res['passes_progressive_distance_y'].mean()
res_avg['pressures_y'] = avg_res['pressures_y'].mean()
res_avg['touches_y'] = avg_res['touches_y'].mean()
res_avg['tackles_y'] = avg_res['tackles_y'].mean()
res_avg
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-34702da87098> in <module>
# ----> 1 res_avg['passes_completed_y'] = list(avg_res['passes_completed_y'].mean())
#       2 res_avg['passes_pct_y'] = avg_res['passes_pct_y'].mean()
#       3 res_avg['passes_progressive_distance_y'] = avg_res['passes_progressive_distance_y'].mean()
#       4 res_avg['pressures_y'] = avg_res['pressures_y'].mean()
#       5 res_avg['touches_y'] = avg_res['touches_y'].mean()
#
# TypeError: 'float' object is not iterable

# %%
avg_res['passes_completed_y'].mean()
# Out:
# 0.5145369666682922

# %%
res_prog = pd.DataFrame()
res_prog.insert(0, 'passes_completed_y', [df['passes_completed_y'].mean()])
res_prog.insert(0, 'passes_pct_y', df['passes_pct_y'].mean())
res_prog.insert(0, 'passes_progressive_distance_y', df['passes_progressive_distance_y'].mean())
res_prog.insert(0, 'pressures_y', df['pressures_y'].mean())
res_prog.insert(0, 'touches_y', df['touches_y'].mean())
res_prog.insert(0, 'tackles_y', df['tackles_y'].mean())
res_prog.insert(0, '', ['model prediction'])
res_prog
# Out:
#                      tackles_y  touches_y  pressures_y  \
# 0  model prediction   0.390054   0.131403     0.206856
#
#    passes_progressive_distance_y  passes_pct_y  passes_completed_y
# 0                       0.346306      0.048721            0.193737

# %%
res_avg = pd.DataFrame()
res_avg.insert(0, 'passes_completed_y', [avg_res['passes_completed_y'].mean()])
res_avg.insert(0, 'passes_pct_y', avg_res['passes_pct_y'].mean())
res_avg.insert(0, 'passes_progressive_distance_y', avg_res['passes_progressive_distance_y'].mean())
res_avg.insert(0, 'pressures_y', avg_res['pressures_y'].mean())
res_avg.insert(0, 'touches_y', avg_res['touches_y'].mean())
res_avg.insert(0, 'tackles_y', avg_res['tackles_y'].mean())
res_avg.insert(0, '', ['average prediction'])
res_avg
# Out:
#                        tackles_y  touches_y  pressures_y  \
# 0  average prediction   0.596528   0.504623     0.514398
#
#    passes_progressive_distance_y  passes_pct_y  passes_completed_y
# 0                        0.57594      0.063364            0.514537

# %%
# Out:
#    tackles_y  touches_y  pressures_y  passes_progressive_distance_y  \
# 0   0.390054   0.131403     0.206856                       0.346306
#
#    passes_pct_y  passes_completed_y
# 0      0.048721            0.193737
